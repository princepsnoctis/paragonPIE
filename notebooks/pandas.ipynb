# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df.head(2)
# Out:
#                                 line          name  quantity price  \
# 0  SOLKAMIENNA 1,1KG A 1 x2,29 2,29A   SOLKAMIENNA         1  2,29
# 1   ZELKIKWASNE 100G A 1 x3,99 3,99A  ZELKI KWASNE         1  3,99
#
#   tax_category unit total_price
# 0            A   kg        2,29
# 1            A    g        3,99

# %%
df.tail(2)
# Out:
#                                  line                  name  quantity price  \
# 9   KLłkEukalMent25ODg H 1SZT x4,99 4      EUKAL MENTOL 25G         1  4,99
# 10  Ka5aosExcl.Indyk9Og t 1SZT x6,79   KASZA EXCL INDYK 90G         1  6,79
#
#    tax_category unit total_price
# 9             H  szt        4,99
# 10            t  szt        6,79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   line          11 non-null     object
#  1   name          11 non-null     object
#  2   quantity      11 non-null     int64
#  3   price         11 non-null     object
#  4   tax_category  11 non-null     object
#  5   unit          11 non-null     object
#  6   total_price   11 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 748.0+ bytes

# %%
df.describe()
# Out:
#         quantity
# count  11.000000
# mean    1.818182
# std     1.250454
# min     1.000000
# 25%     1.000000
# 50%     1.000000
# 75%     2.500000
# max     4.000000

# %%
df["price"]
# Out:
# 0      2,29
# 1      3,99
# 2      2,99
# 3      7,19
# 4      1,59
# 5      9,99
# 6     14,49
# 7     10,50
# 8      1,80
# 9      4,99
# 10     6,79
# Name: price, dtype: object

# %%
df[["price", "quantity"]]
# Out:
#     price  quantity
# 0    2,29         1
# 1    3,99         1
# 2    2,99         1
# 3    7,19         4
# 4    1,59         2
# 5    9,99         1
# 6   14,49         1
# 7   10,50         3
# 8    1,80         4
# 9    4,99         1
# 10   6,79         1

# %%
df.loc[0]
# Out:
# line            SOLKAMIENNA 1,1KG A 1 x2,29 2,29A
# name                                  SOLKAMIENNA
# quantity                                        1
# price                                        2,29
# tax_category                                    A
# unit                                           kg
# total_price                                  2,29
# Name: 0, dtype: object

# %%
df.loc[0:2]
# Out:
#                                  line            name  quantity price  \
# 0   SOLKAMIENNA 1,1KG A 1 x2,29 2,29A     SOLKAMIENNA         1  2,29
# 1    ZELKIKWASNE 100G A 1 x3,99 3,99A    ZELKI KWASNE         1  3,99
# 2  PRZYPRAWA W PL 200 B 1 x2,99 2,99B  PRZYPRAWA W PL         1  2,99
#
#   tax_category unit total_price
# 0            A   kg        2,29
# 1            A    g        3,99
# 2            B    g        2,99

# %%
df.iloc[0]
# Out:
# line            SOLKAMIENNA 1,1KG A 1 x2,29 2,29A
# name                                  SOLKAMIENNA
# quantity                                        1
# price                                        2,29
# tax_category                                    A
# unit                                           kg
# total_price                                  2,29
# Name: 0, dtype: object

# %%
df[df["quantity"] == 1]
# Out:
#                                   line                       name  quantity  \
# 0    SOLKAMIENNA 1,1KG A 1 x2,29 2,29A                SOLKAMIENNA         1
# 1     ZELKIKWASNE 100G A 1 x3,99 3,99A               ZELKI KWASNE         1
# 2   PRZYPRAWA W PL 200 B 1 x2,99 2,99B             PRZYPRAWA W PL         1
# 5   KONCENTRAT POM 900 C 1 x9,99 9,99C  KONCENTRAT POMIDOROWY 900         1
# 6     KAPUSTA 3,1 KG C 1 x14,49 14,49C                    KAPUSTA         1
# 9    KLłkEukalMent25ODg H 1SZT x4,99 4           EUKAL MENTOL 25G         1
# 10   Ka5aosExcl.Indyk9Og t 1SZT x6,79        KASZA EXCL INDYK 90G         1
#
#     price tax_category unit total_price
# 0    2,29            A   kg        2,29
# 1    3,99            A    g        3,99
# 2    2,99            B    g        2,99
# 5    9,99            C    g        9,99
# 6   14,49            C   kg       14,49
# 9    4,99            H  szt        4,99
# 10   6,79            t  szt        6,79

# %%
df["quantity"].plot()
# Out:
# <Axes: >
